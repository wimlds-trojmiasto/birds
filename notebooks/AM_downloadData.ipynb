# %%
#!/usr/bin/env/python
#
# A script to download bird sound files from the www.xeno-canto.org archives with metadata
# The program downloads all the files found with the search terms into
# subdirectory data/xeno-canto-dataset/searchTerm.
# and corresponding json files.

# Karoliina Oksanen, 2014
# Updated to python 3.7.4, Agnieszka Mikolajczyk, 2019
# Added json download, and extraction of metadata from json, Agnieszka Mikolajczyk 2019

import urllib.request, json
import sys
import os


# returns the Xeno Canto catalogue numbers for the given list of search terms.
# @param searchTerms: list of search terms
# http://www.xeno-canto.org/explore?query=common+snipe


# Creates the subdirectory data/xeno-canto-dataset if necessary
# Downloads and saves json files for number of pages in a query
# and directory path to saved json's
def save_json(searchTerms, birdName, country):
    numPages = 1
    page = 1
    # create a path to save json files and recordings
    path = "../data/xeno-canto-dataset-full/" + birdName.replace(':', '') + "/" + country
    if not os.path.exists(path):
        print("Creating subdirectory " + path + " for downloaded files...")
        os.makedirs(path)
        # download a json file for every page found in a query
    while page < numPages + 1:
        print("Loading page " + str(page) + "...")
        url = 'https://www.xeno-canto.org/api/2/recordings?query={0}&page={1}'.format(searchTerms.replace(' ', '%20'),
                                                                                      page)
        print(url)
        jsonPage = urllib.request.urlopen(url)
        jsondata = json.loads(jsonPage.read().decode('utf-8'))
        filename = path + "/jsondata_p" + str(page) + ".json"
        with open(filename, 'w') as outfile:
            json.dump(jsondata, outfile)
        # check number of pages
        numPages = jsondata['numPages']
        page = page + 1
    print("Found ", numPages, " pages in total.")
    # return number of files in json
    # each page contains 500 results, the last page can have less than 500 records
    print("Saved json for ", (numPages - 1) * 500 + len(jsondata['recordings']), " files")
    return path


# reads the json and return the list of values for selected json part
# i.e. "id" - ID number, "type": type of the bird sound such as call or song
# for all Xeno Canto files found with the given search terms.
def read_data(searchTerm, path):
    data = []
    numPages = 1
    page = 1
    # read all pages and save results in a list
    while page < numPages + 1:
        # read file
        with open(path + "/jsondata_p" + str(page) + ".json", 'r') as jsonfile:
            jsondata = jsonfile.read()
        jsondata = json.loads(jsondata)
        # check number of pages
        numPages = jsondata['numPages']
        # find "recordings" in a json and save a list with a search term
        for k in range(len(jsondata['recordings'])):
            data.append(jsondata["recordings"][k][searchTerm])
        page = page + 1
    return data


# downloads all sound files found with the search terms into xeno-canto directory
# into catalogue named after the search term (i.e. Apus apus)
# filename have two parts: the name of the bird in latin and ID number
def download(searchTerms, birdName, country):
    # create data/xeno-canto-dataset directory
    path = save_json(searchTerms, birdName, country)
    # get filenames: recording ID and bird name in latin from json
    filenamesID = read_data('id', path)
    filenamesCountry = read_data('cnt', path)
    # get website recording http download address from json
    fileaddress = read_data('file', path)
    numfiles = len(filenamesID)
    print("A total of ", numfiles, " files will be downloaded")
    for i in range(0, numfiles):
        print("Saving file ", i + 1, "/", numfiles,
              ": data/xeno-canto-dataset-full/" + birdName.replace(':', '') + filenamesID[
                  i] + ".mp3")
        urllib.request.urlretrieve("http:" + fileaddress[i],
                                   path + "/" + birdName + filenamesID[i] + ".mp3")


def main(argv):
    # download all sounds type song, from bird list recorded in selected countries 
    countries = ['Poland', 'Germany', 'Slovakia', 'Czech', 'Lithuania']
    birds = ['Dendrocopos major',
             'Chloris chloris',
             'Corvus frugilegus',
             'Coccothraustes coccothraustes',
             'Columba palumbus',
             'Delichon urbicum',
             'Apus apus',
             'Sitta europaea',
             'Corvus monedula',
             'Phoenicurus ochruros',
             'Turdus merula',
             'Turdus pilaris',
             'Passer montanus',
             'Phylloscopus trochilus',
             'Phylloscopus collybita',
             'Phoenicurus phoenicurus',
             'Motacilla alba',
             'Erithacus rubecula',
             'Streptopelia decaocto',
             'Parus major',
             'Parus caeruleus',
             'Alauda arvensis',
             'Luscinia luscinia',
             'Garrulus glandarius',
             'Turdus philomelos',
             'Pica pica',
             'Troglodytes troglodytes',
             'Carduelis carduelis',
             'Sturnus vulgaris',
             'Emberiza citrinella',
             'Passer domesticus',
             'Corvus corone',
             'Fringilla coelebs']
             
    for country in countries:
        for bird in birds:
            download(bird + ' cnt:' + country + ' type:song', bird.replace(' ', ''), country)


if __name__ == "__main__":
    main(sys.argv)
# Out:
# Creating subdirectory ../data/xeno-canto-dataset-full/Dendrocoposmajor/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Dendrocopos%20major%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Chlorischloris/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Chloris%20chloris%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  37  files
# A total of  37  files will be downloaded
# Saving file  1 / 37 : data/xeno-canto-dataset-full/Chlorischloris486002.mp3
# Saving file  2 / 37 : data/xeno-canto-dataset-full/Chlorischloris466837.mp3
# Saving file  3 / 37 : data/xeno-canto-dataset-full/Chlorischloris464711.mp3
# Saving file  4 / 37 : data/xeno-canto-dataset-full/Chlorischloris463673.mp3
# Saving file  5 / 37 : data/xeno-canto-dataset-full/Chlorischloris462999.mp3
# Saving file  6 / 37 : data/xeno-canto-dataset-full/Chlorischloris462997.mp3
# Saving file  7 / 37 : data/xeno-canto-dataset-full/Chlorischloris462491.mp3
# Saving file  8 / 37 : data/xeno-canto-dataset-full/Chlorischloris462151.mp3
# Saving file  9 / 37 : data/xeno-canto-dataset-full/Chlorischloris461390.mp3
# Saving file  10 / 37 : data/xeno-canto-dataset-full/Chlorischloris461388.mp3
# Saving file  11 / 37 : data/xeno-canto-dataset-full/Chlorischloris327983.mp3
# Saving file  12 / 37 : data/xeno-canto-dataset-full/Chlorischloris202315.mp3
# Saving file  13 / 37 : data/xeno-canto-dataset-full/Chlorischloris140580.mp3
# Saving file  14 / 37 : data/xeno-canto-dataset-full/Chlorischloris129478.mp3
# Saving file  15 / 37 : data/xeno-canto-dataset-full/Chlorischloris129476.mp3
# Saving file  16 / 37 : data/xeno-canto-dataset-full/Chlorischloris127313.mp3
# Saving file  17 / 37 : data/xeno-canto-dataset-full/Chlorischloris123547.mp3
# Saving file  18 / 37 : data/xeno-canto-dataset-full/Chlorischloris123546.mp3
# Saving file  19 / 37 : data/xeno-canto-dataset-full/Chlorischloris122456.mp3
# Saving file  20 / 37 : data/xeno-canto-dataset-full/Chlorischloris103775.mp3
# Saving file  21 / 37 : data/xeno-canto-dataset-full/Chlorischloris44996.mp3
# Saving file  22 / 37 : data/xeno-canto-dataset-full/Chlorischloris43772.mp3
# Saving file  23 / 37 : data/xeno-canto-dataset-full/Chlorischloris464712.mp3
# Saving file  24 / 37 : data/xeno-canto-dataset-full/Chlorischloris463027.mp3
# Saving file  25 / 37 : data/xeno-canto-dataset-full/Chlorischloris355779.mp3
# Saving file  26 / 37 : data/xeno-canto-dataset-full/Chlorischloris327900.mp3
# Saving file  27 / 37 : data/xeno-canto-dataset-full/Chlorischloris321361.mp3
# Saving file  28 / 37 : data/xeno-canto-dataset-full/Chlorischloris299193.mp3
# Saving file  29 / 37 : data/xeno-canto-dataset-full/Chlorischloris255106.mp3
# Saving file  30 / 37 : data/xeno-canto-dataset-full/Chlorischloris143456.mp3
# Saving file  31 / 37 : data/xeno-canto-dataset-full/Chlorischloris121007.mp3
# Saving file  32 / 37 : data/xeno-canto-dataset-full/Chlorischloris102100.mp3
# Saving file  33 / 37 : data/xeno-canto-dataset-full/Chlorischloris91122.mp3
# Saving file  34 / 37 : data/xeno-canto-dataset-full/Chlorischloris91121.mp3
# Saving file  35 / 37 : data/xeno-canto-dataset-full/Chlorischloris91119.mp3
# Saving file  36 / 37 : data/xeno-canto-dataset-full/Chlorischloris305377.mp3
# Saving file  37 / 37 : data/xeno-canto-dataset-full/Chlorischloris36406.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Corvusfrugilegus/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Corvus%20frugilegus%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  1  files
# A total of  1  files will be downloaded
# Saving file  1 / 1 : data/xeno-canto-dataset-full/Corvusfrugilegus413825.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Coccothraustescoccothraustes/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Coccothraustes%20coccothraustes%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  10  files
# A total of  10  files will be downloaded
# Saving file  1 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes353999.mp3
# Saving file  2 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes210479.mp3
# Saving file  3 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes130049.mp3
# Saving file  4 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes121015.mp3
# Saving file  5 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes100765.mp3
# Saving file  6 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes90988.mp3
# Saving file  7 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes461599.mp3
# Saving file  8 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes328387.mp3
# Saving file  9 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes314606.mp3
# Saving file  10 / 10 : data/xeno-canto-dataset-full/Coccothraustescoccothraustes354001.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Columbapalumbus/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Columba%20palumbus%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  15  files
# A total of  15  files will be downloaded
# Saving file  1 / 15 : data/xeno-canto-dataset-full/Columbapalumbus469724.mp3
# Saving file  2 / 15 : data/xeno-canto-dataset-full/Columbapalumbus462990.mp3
# Saving file  3 / 15 : data/xeno-canto-dataset-full/Columbapalumbus462348.mp3
# Saving file  4 / 15 : data/xeno-canto-dataset-full/Columbapalumbus462148.mp3
# Saving file  5 / 15 : data/xeno-canto-dataset-full/Columbapalumbus314368.mp3
# Saving file  6 / 15 : data/xeno-canto-dataset-full/Columbapalumbus246655.mp3
# Saving file  7 / 15 : data/xeno-canto-dataset-full/Columbapalumbus479853.mp3
# Saving file  8 / 15 : data/xeno-canto-dataset-full/Columbapalumbus317919.mp3
# Saving file  9 / 15 : data/xeno-canto-dataset-full/Columbapalumbus245835.mp3
# Saving file  10 / 15 : data/xeno-canto-dataset-full/Columbapalumbus181212.mp3
# Saving file  11 / 15 : data/xeno-canto-dataset-full/Columbapalumbus181211.mp3
# Saving file  12 / 15 : data/xeno-canto-dataset-full/Columbapalumbus91193.mp3
# Saving file  13 / 15 : data/xeno-canto-dataset-full/Columbapalumbus130072.mp3
# Saving file  14 / 15 : data/xeno-canto-dataset-full/Columbapalumbus103240.mp3
# Saving file  15 / 15 : data/xeno-canto-dataset-full/Columbapalumbus103239.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Delichonurbicum/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Delichon%20urbicum%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  2  files
# A total of  2  files will be downloaded
# Saving file  1 / 2 : data/xeno-canto-dataset-full/Delichonurbicum181145.mp3
# Saving file  2 / 2 : data/xeno-canto-dataset-full/Delichonurbicum344098.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Apusapus/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Apus%20apus%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  2  files
# A total of  2  files will be downloaded
# Saving file  1 / 2 : data/xeno-canto-dataset-full/Apusapus302766.mp3
# Saving file  2 / 2 : data/xeno-canto-dataset-full/Apusapus179170.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Sittaeuropaea/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Sitta%20europaea%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  35  files
# A total of  35  files will be downloaded
# Saving file  1 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea463195.mp3
# Saving file  2 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea463191.mp3
# Saving file  3 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea462740.mp3
# Saving file  4 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea459838.mp3
# Saving file  5 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea459830.mp3
# Saving file  6 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea407887.mp3
# Saving file  7 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea358795.mp3
# Saving file  8 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea348567.mp3
# Saving file  9 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea313930.mp3
# Saving file  10 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea310154.mp3
# Saving file  11 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea309989.mp3
# Saving file  12 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea235146.mp3
# Saving file  13 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea171592.mp3
# Saving file  14 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea170495.mp3
# Saving file  15 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea168069.mp3
# Saving file  16 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea130210.mp3
# Saving file  17 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea127264.mp3
# Saving file  18 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea127263.mp3
# Saving file  19 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea123539.mp3
# Saving file  20 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea122457.mp3
# Saving file  21 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea113906.mp3
# Saving file  22 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea465127.mp3
# Saving file  23 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea463674.mp3
# Saving file  24 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea455700.mp3
# Saving file  25 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea409776.mp3
# Saving file  26 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea363007.mp3
# Saving file  27 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea362662.mp3
# Saving file  28 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea362660.mp3
# Saving file  29 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea358873.mp3
# Saving file  30 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea358872.mp3
# Saving file  31 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea310752.mp3
# Saving file  32 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea309361.mp3
# Saving file  33 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea307938.mp3
# Saving file  34 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea170775.mp3
# Saving file  35 / 35 : data/xeno-canto-dataset-full/Sittaeuropaea361576.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Corvusmonedula/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Corvus%20monedula%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Phoenicurusochruros/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Phoenicurus%20ochruros%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  30  files
# A total of  30  files will be downloaded
# Saving file  1 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros483356.mp3
# Saving file  2 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros483355.mp3
# Saving file  3 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros470689.mp3
# Saving file  4 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros459868.mp3
# Saving file  5 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros346214.mp3
# Saving file  6 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros346213.mp3
# Saving file  7 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros327883.mp3
# Saving file  8 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros310132.mp3
# Saving file  9 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros199758.mp3
# Saving file  10 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros132603.mp3
# Saving file  11 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros110688.mp3
# Saving file  12 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros110687.mp3
# Saving file  13 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros100012.mp3
# Saving file  14 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93486.mp3
# Saving file  15 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93480.mp3
# Saving file  16 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93475.mp3
# Saving file  17 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93474.mp3
# Saving file  18 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93473.mp3
# Saving file  19 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros497105.mp3
# Saving file  20 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros465619.mp3
# Saving file  21 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros366713.mp3
# Saving file  22 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros311594.mp3
# Saving file  23 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros174249.mp3
# Saving file  24 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93484.mp3
# Saving file  25 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93483.mp3
# Saving file  26 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93481.mp3
# Saving file  27 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros90876.mp3
# Saving file  28 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros93485.mp3
# Saving file  29 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros462799.mp3
# Saving file  30 / 30 : data/xeno-canto-dataset-full/Phoenicurusochruros240223.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Turdusmerula/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Turdus%20merula%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  56  files
# A total of  56  files will be downloaded
# Saving file  1 / 56 : data/xeno-canto-dataset-full/Turdusmerula495519.mp3
# Saving file  2 / 56 : data/xeno-canto-dataset-full/Turdusmerula478738.mp3
# Saving file  3 / 56 : data/xeno-canto-dataset-full/Turdusmerula465284.mp3
# Saving file  4 / 56 : data/xeno-canto-dataset-full/Turdusmerula462390.mp3
# Saving file  5 / 56 : data/xeno-canto-dataset-full/Turdusmerula461061.mp3
# Saving file  6 / 56 : data/xeno-canto-dataset-full/Turdusmerula448570.mp3
# Saving file  7 / 56 : data/xeno-canto-dataset-full/Turdusmerula420100.mp3
# Saving file  8 / 56 : data/xeno-canto-dataset-full/Turdusmerula414529.mp3
# Saving file  9 / 56 : data/xeno-canto-dataset-full/Turdusmerula370373.mp3
# Saving file  10 / 56 : data/xeno-canto-dataset-full/Turdusmerula314165.mp3
# Saving file  11 / 56 : data/xeno-canto-dataset-full/Turdusmerula310140.mp3
# Saving file  12 / 56 : data/xeno-canto-dataset-full/Turdusmerula150613.mp3
# Saving file  13 / 56 : data/xeno-canto-dataset-full/Turdusmerula132596.mp3
# Saving file  14 / 56 : data/xeno-canto-dataset-full/Turdusmerula132594.mp3
# Saving file  15 / 56 : data/xeno-canto-dataset-full/Turdusmerula132593.mp3
# Saving file  16 / 56 : data/xeno-canto-dataset-full/Turdusmerula132592.mp3
# Saving file  17 / 56 : data/xeno-canto-dataset-full/Turdusmerula130204.mp3
# Saving file  18 / 56 : data/xeno-canto-dataset-full/Turdusmerula129736.mp3
# Saving file  19 / 56 : data/xeno-canto-dataset-full/Turdusmerula129469.mp3
# Saving file  20 / 56 : data/xeno-canto-dataset-full/Turdusmerula129216.mp3
# Saving file  21 / 56 : data/xeno-canto-dataset-full/Turdusmerula128820.mp3
# Saving file  22 / 56 : data/xeno-canto-dataset-full/Turdusmerula127998.mp3
# Saving file  23 / 56 : data/xeno-canto-dataset-full/Turdusmerula122933.mp3
# Saving file  24 / 56 : data/xeno-canto-dataset-full/Turdusmerula122777.mp3
# Saving file  25 / 56 : data/xeno-canto-dataset-full/Turdusmerula122475.mp3
# Saving file  26 / 56 : data/xeno-canto-dataset-full/Turdusmerula116939.mp3
# Saving file  27 / 56 : data/xeno-canto-dataset-full/Turdusmerula105116.mp3
# Saving file  28 / 56 : data/xeno-canto-dataset-full/Turdusmerula102103.mp3
# Saving file  29 / 56 : data/xeno-canto-dataset-full/Turdusmerula92831.mp3
# Saving file  30 / 56 : data/xeno-canto-dataset-full/Turdusmerula90889.mp3
# Saving file  31 / 56 : data/xeno-canto-dataset-full/Turdusmerula46194.mp3
# Saving file  32 / 56 : data/xeno-canto-dataset-full/Turdusmerula45002.mp3
# Saving file  33 / 56 : data/xeno-canto-dataset-full/Turdusmerula459259.mp3
# Saving file  34 / 56 : data/xeno-canto-dataset-full/Turdusmerula448585.mp3
# Saving file  35 / 56 : data/xeno-canto-dataset-full/Turdusmerula448560.mp3
# Saving file  36 / 56 : data/xeno-canto-dataset-full/Turdusmerula358614.mp3
# Saving file  37 / 56 : data/xeno-canto-dataset-full/Turdusmerula357906.mp3
# Saving file  38 / 56 : data/xeno-canto-dataset-full/Turdusmerula326506.mp3
# Saving file  39 / 56 : data/xeno-canto-dataset-full/Turdusmerula310755.mp3
# Saving file  40 / 56 : data/xeno-canto-dataset-full/Turdusmerula308112.mp3
# Saving file  41 / 56 : data/xeno-canto-dataset-full/Turdusmerula252966.mp3
# Saving file  42 / 56 : data/xeno-canto-dataset-full/Turdusmerula252882.mp3
# Saving file  43 / 56 : data/xeno-canto-dataset-full/Turdusmerula245679.mp3
# Saving file  44 / 56 : data/xeno-canto-dataset-full/Turdusmerula198250.mp3
# Saving file  45 / 56 : data/xeno-canto-dataset-full/Turdusmerula170786.mp3
# Saving file  46 / 56 : data/xeno-canto-dataset-full/Turdusmerula155897.mp3
# Saving file  47 / 56 : data/xeno-canto-dataset-full/Turdusmerula148721.mp3
# Saving file  48 / 56 : data/xeno-canto-dataset-full/Turdusmerula144196.mp3
# Saving file  49 / 56 : data/xeno-canto-dataset-full/Turdusmerula132618.mp3
# Saving file  50 / 56 : data/xeno-canto-dataset-full/Turdusmerula121327.mp3
# Saving file  51 / 56 : data/xeno-canto-dataset-full/Turdusmerula486567.mp3
# Saving file  52 / 56 : data/xeno-canto-dataset-full/Turdusmerula482576.mp3
# Saving file  53 / 56 : data/xeno-canto-dataset-full/Turdusmerula419672.mp3
# Saving file  54 / 56 : data/xeno-canto-dataset-full/Turdusmerula330440.mp3
# Saving file  55 / 56 : data/xeno-canto-dataset-full/Turdusmerula310754.mp3
# Saving file  56 / 56 : data/xeno-canto-dataset-full/Turdusmerula419856.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Turduspilaris/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Turdus%20pilaris%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  14  files
# A total of  14  files will be downloaded
# Saving file  1 / 14 : data/xeno-canto-dataset-full/Turduspilaris462960.mp3
# Saving file  2 / 14 : data/xeno-canto-dataset-full/Turduspilaris482707.mp3
# Saving file  3 / 14 : data/xeno-canto-dataset-full/Turduspilaris463555.mp3
# Saving file  4 / 14 : data/xeno-canto-dataset-full/Turduspilaris462961.mp3
# Saving file  5 / 14 : data/xeno-canto-dataset-full/Turduspilaris462956.mp3
# Saving file  6 / 14 : data/xeno-canto-dataset-full/Turduspilaris462140.mp3
# Saving file  7 / 14 : data/xeno-canto-dataset-full/Turduspilaris421686.mp3
# Saving file  8 / 14 : data/xeno-canto-dataset-full/Turduspilaris175093.mp3
# Saving file  9 / 14 : data/xeno-canto-dataset-full/Turduspilaris153794.mp3
# Saving file  10 / 14 : data/xeno-canto-dataset-full/Turduspilaris100967.mp3
# Saving file  11 / 14 : data/xeno-canto-dataset-full/Turduspilaris100966.mp3
# Saving file  12 / 14 : data/xeno-canto-dataset-full/Turduspilaris91110.mp3
# Saving file  13 / 14 : data/xeno-canto-dataset-full/Turduspilaris477663.mp3
# Saving file  14 / 14 : data/xeno-canto-dataset-full/Turduspilaris421688.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Passermontanus/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Passer%20montanus%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  11  files
# A total of  11  files will be downloaded
# Saving file  1 / 11 : data/xeno-canto-dataset-full/Passermontanus462606.mp3
# Saving file  2 / 11 : data/xeno-canto-dataset-full/Passermontanus462144.mp3
# Saving file  3 / 11 : data/xeno-canto-dataset-full/Passermontanus404958.mp3
# Saving file  4 / 11 : data/xeno-canto-dataset-full/Passermontanus308343.mp3
# Saving file  5 / 11 : data/xeno-canto-dataset-full/Passermontanus213537.mp3
# Saving file  6 / 11 : data/xeno-canto-dataset-full/Passermontanus210487.mp3
# Saving file  7 / 11 : data/xeno-canto-dataset-full/Passermontanus168663.mp3
# Saving file  8 / 11 : data/xeno-canto-dataset-full/Passermontanus121014.mp3
# Saving file  9 / 11 : data/xeno-canto-dataset-full/Passermontanus91173.mp3
# Saving file  10 / 11 : data/xeno-canto-dataset-full/Passermontanus43764.mp3
# Saving file  11 / 11 : data/xeno-canto-dataset-full/Passermontanus178807.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Phylloscopustrochilus/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Phylloscopus%20trochilus%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  67  files
# A total of  67  files will be downloaded
# Saving file  1 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus485632.mp3
# Saving file  2 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus477809.mp3
# Saving file  3 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus477534.mp3
# Saving file  4 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus470779.mp3
# Saving file  5 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus448597.mp3
# Saving file  6 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus448590.mp3
# Saving file  7 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus376586.mp3
# Saving file  8 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus312654.mp3
# Saving file  9 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus312653.mp3
# Saving file  10 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus235177.mp3
# Saving file  11 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus179562.mp3
# Saving file  12 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus178022.mp3
# Saving file  13 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus176283.mp3
# Saving file  14 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus174638.mp3
# Saving file  15 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus174344.mp3
# Saving file  16 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus173015.mp3
# Saving file  17 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus173013.mp3
# Saving file  18 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus172958.mp3
# Saving file  19 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus153718.mp3
# Saving file  20 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus141721.mp3
# Saving file  21 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus133410.mp3
# Saving file  22 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus132709.mp3
# Saving file  23 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus132708.mp3
# Saving file  24 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus130276.mp3
# Saving file  25 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus130275.mp3
# Saving file  26 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus129514.mp3
# Saving file  27 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus120940.mp3
# Saving file  28 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus116940.mp3
# Saving file  29 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus113737.mp3
# Saving file  30 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus103994.mp3
# Saving file  31 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus103882.mp3
# Saving file  32 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus100764.mp3
# Saving file  33 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus91190.mp3
# Saving file  34 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus502198.mp3
# Saving file  35 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus483728.mp3
# Saving file  36 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus482584.mp3
# Saving file  37 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus477532.mp3
# Saving file  38 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus416096.mp3
# Saving file  39 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus415105.mp3
# Saving file  40 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus414530.mp3
# Saving file  41 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus412990.mp3
# Saving file  42 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus367228.mp3
# Saving file  43 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus367062.mp3
# Saving file  44 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus364566.mp3
# Saving file  45 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus363792.mp3
# Saving file  46 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus356355.mp3
# Saving file  47 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus315981.mp3
# Saving file  48 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus315980.mp3
# Saving file  49 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus315976.mp3
# Saving file  50 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus313415.mp3
# Saving file  51 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus313414.mp3
# Saving file  52 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus313413.mp3
# Saving file  53 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus313103.mp3
# Saving file  54 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus312869.mp3
# Saving file  55 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus312825.mp3
# Saving file  56 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus268426.mp3
# Saving file  57 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus254854.mp3
# Saving file  58 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus237306.mp3
# Saving file  59 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus175498.mp3
# Saving file  60 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus175496.mp3
# Saving file  61 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus173806.mp3
# Saving file  62 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus140467.mp3
# Saving file  63 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus412055.mp3
# Saving file  64 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus385686.mp3
# Saving file  65 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus356354.mp3
# Saving file  66 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus312826.mp3
# Saving file  67 / 67 : data/xeno-canto-dataset-full/Phylloscopustrochilus246715.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Phylloscopuscollybita/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Phylloscopus%20collybita%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  107  files
# A total of  107  files will be downloaded
# Saving file  1 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita504432.mp3
# Saving file  2 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita504431.mp3
# Saving file  3 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita478475.mp3
# Saving file  4 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita466234.mp3
# Saving file  5 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita465565.mp3
# Saving file  6 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita465287.mp3
# Saving file  7 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita464612.mp3
# Saving file  8 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita464034.mp3
# Saving file  9 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita463811.mp3
# Saving file  10 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita463752.mp3
# Saving file  11 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita421683.mp3
# Saving file  12 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita325319.mp3
# Saving file  13 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita313421.mp3
# Saving file  14 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita313420.mp3
# Saving file  15 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita313419.mp3
# Saving file  16 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita311599.mp3
# Saving file  17 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita246021.mp3
# Saving file  18 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita244263.mp3
# Saving file  19 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita184492.mp3
# Saving file  20 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita181193.mp3
# Saving file  21 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita179246.mp3
# Saving file  22 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita178854.mp3
# Saving file  23 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita174679.mp3
# Saving file  24 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita174678.mp3
# Saving file  25 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita174637.mp3
# Saving file  26 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita174349.mp3
# Saving file  27 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita173814.mp3
# Saving file  28 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita171843.mp3
# Saving file  29 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita135425.mp3
# Saving file  30 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita133155.mp3
# Saving file  31 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita132620.mp3
# Saving file  32 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita131267.mp3
# Saving file  33 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita129459.mp3
# Saving file  34 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita104358.mp3
# Saving file  35 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103830.mp3
# Saving file  36 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103829.mp3
# Saving file  37 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103826.mp3
# Saving file  38 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103825.mp3
# Saving file  39 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103823.mp3
# Saving file  40 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103822.mp3
# Saving file  41 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103535.mp3
# Saving file  42 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103404.mp3
# Saving file  43 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103014.mp3
# Saving file  44 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita99953.mp3
# Saving file  45 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita99906.mp3
# Saving file  46 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita90927.mp3
# Saving file  47 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita90851.mp3
# Saving file  48 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita488493.mp3
# Saving file  49 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita483846.mp3
# Saving file  50 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita483704.mp3
# Saving file  51 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita477295.mp3
# Saving file  52 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita470685.mp3
# Saving file  53 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita470681.mp3
# Saving file  54 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita467281.mp3
# Saving file  55 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita465128.mp3
# Saving file  56 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita464840.mp3
# Saving file  57 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita413002.mp3
# Saving file  58 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita375154.mp3
# Saving file  59 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita367230.mp3
# Saving file  60 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363730.mp3
# Saving file  61 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363729.mp3
# Saving file  62 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363728.mp3
# Saving file  63 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363413.mp3
# Saving file  64 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363411.mp3
# Saving file  65 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363410.mp3
# Saving file  66 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363001.mp3
# Saving file  67 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363000.mp3
# Saving file  68 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita362769.mp3
# Saving file  69 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita360778.mp3
# Saving file  70 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita356361.mp3
# Saving file  71 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita356358.mp3
# Saving file  72 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita336775.mp3
# Saving file  73 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita336774.mp3
# Saving file  74 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita318048.mp3
# Saving file  75 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita316639.mp3
# Saving file  76 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita313928.mp3
# Saving file  77 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita313927.mp3
# Saving file  78 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita283898.mp3
# Saving file  79 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita240008.mp3
# Saving file  80 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita240007.mp3
# Saving file  81 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita197887.mp3
# Saving file  82 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita177975.mp3
# Saving file  83 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita177714.mp3
# Saving file  84 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita138446.mp3
# Saving file  85 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita138445.mp3
# Saving file  86 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita134605.mp3
# Saving file  87 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita134098.mp3
# Saving file  88 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita134094.mp3
# Saving file  89 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita133160.mp3
# Saving file  90 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita124635.mp3
# Saving file  91 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita110684.mp3
# Saving file  92 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita103833.mp3
# Saving file  93 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita101106.mp3
# Saving file  94 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita25517.mp3
# Saving file  95 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita375113.mp3
# Saving file  96 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita375110.mp3
# Saving file  97 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363727.mp3
# Saving file  98 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita362768.mp3
# Saving file  99 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita356360.mp3
# Saving file  100 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita356357.mp3
# Saving file  101 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita356356.mp3
# Saving file  102 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita310750.mp3
# Saving file  103 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita241599.mp3
# Saving file  104 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita218177.mp3
# Saving file  105 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita443016.mp3
# Saving file  106 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita363726.mp3
# Saving file  107 / 107 : data/xeno-canto-dataset-full/Phylloscopuscollybita350192.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Phoenicurusphoenicurus/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Phoenicurus%20phoenicurus%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  37  files
# A total of  37  files will be downloaded
# Saving file  1 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus467934.mp3
# Saving file  2 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus425495.mp3
# Saving file  3 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus413703.mp3
# Saving file  4 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus412285.mp3
# Saving file  5 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus371665.mp3
# Saving file  6 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus328382.mp3
# Saving file  7 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus312901.mp3
# Saving file  8 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus253022.mp3
# Saving file  9 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus180312.mp3
# Saving file  10 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus178574.mp3
# Saving file  11 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus178573.mp3
# Saving file  12 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus133383.mp3
# Saving file  13 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus132700.mp3
# Saving file  14 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus103225.mp3
# Saving file  15 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus103224.mp3
# Saving file  16 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus101378.mp3
# Saving file  17 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus100758.mp3
# Saving file  18 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus90976.mp3
# Saving file  19 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus468416.mp3
# Saving file  20 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus442115.mp3
# Saving file  21 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus442111.mp3
# Saving file  22 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus367523.mp3
# Saving file  23 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus333510.mp3
# Saving file  24 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus318649.mp3
# Saving file  25 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus315255.mp3
# Saving file  26 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus253020.mp3
# Saving file  27 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus253019.mp3
# Saving file  28 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus237302.mp3
# Saving file  29 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus102063.mp3
# Saving file  30 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus102062.mp3
# Saving file  31 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus100312.mp3
# Saving file  32 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus415501.mp3
# Saving file  33 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus367524.mp3
# Saving file  34 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus241359.mp3
# Saving file  35 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus124752.mp3
# Saving file  36 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus297672.mp3
# Saving file  37 / 37 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus297671.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Motacillaalba/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Motacilla%20alba%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  6  files
# A total of  6  files will be downloaded
# Saving file  1 / 6 : data/xeno-canto-dataset-full/Motacillaalba246013.mp3
# Saving file  2 / 6 : data/xeno-canto-dataset-full/Motacillaalba234882.mp3
# Saving file  3 / 6 : data/xeno-canto-dataset-full/Motacillaalba180311.mp3
# Saving file  4 / 6 : data/xeno-canto-dataset-full/Motacillaalba152630.mp3
# Saving file  5 / 6 : data/xeno-canto-dataset-full/Motacillaalba416761.mp3
# Saving file  6 / 6 : data/xeno-canto-dataset-full/Motacillaalba124274.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Erithacusrubecula/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Erithacus%20rubecula%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  60  files
# A total of  60  files will be downloaded
# Saving file  1 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula477555.mp3
# Saving file  2 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula477536.mp3
# Saving file  3 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula464505.mp3
# Saving file  4 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula464028.mp3
# Saving file  5 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula461648.mp3
# Saving file  6 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula448598.mp3
# Saving file  7 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula448588.mp3
# Saving file  8 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula425839.mp3
# Saving file  9 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula422093.mp3
# Saving file  10 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula421792.mp3
# Saving file  11 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula417295.mp3
# Saving file  12 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula413415.mp3
# Saving file  13 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula412557.mp3
# Saving file  14 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula408133.mp3
# Saving file  15 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula317906.mp3
# Saving file  16 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula314196.mp3
# Saving file  17 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula310156.mp3
# Saving file  18 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula252403.mp3
# Saving file  19 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula252402.mp3
# Saving file  20 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula252291.mp3
# Saving file  21 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula252289.mp3
# Saving file  22 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula237533.mp3
# Saving file  23 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula234111.mp3
# Saving file  24 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula140556.mp3
# Saving file  25 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula136659.mp3
# Saving file  26 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula129743.mp3
# Saving file  27 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula129481.mp3
# Saving file  28 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula129479.mp3
# Saving file  29 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula120943.mp3
# Saving file  30 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula103885.mp3
# Saving file  31 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula103405.mp3
# Saving file  32 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula102082.mp3
# Saving file  33 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula93003.mp3
# Saving file  34 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula93002.mp3
# Saving file  35 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula91155.mp3
# Saving file  36 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula91153.mp3
# Saving file  37 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula493916.mp3
# Saving file  38 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula467282.mp3
# Saving file  39 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula465667.mp3
# Saving file  40 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula457527.mp3
# Saving file  41 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula362665.mp3
# Saving file  42 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula362664.mp3
# Saving file  43 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula317916.mp3
# Saving file  44 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula316662.mp3
# Saving file  45 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula237532.mp3
# Saving file  46 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula176216.mp3
# Saving file  47 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula176215.mp3
# Saving file  48 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula170784.mp3
# Saving file  49 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula155787.mp3
# Saving file  50 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula155572.mp3
# Saving file  51 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula149884.mp3
# Saving file  52 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula149883.mp3
# Saving file  53 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula134097.mp3
# Saving file  54 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula127452.mp3
# Saving file  55 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula395293.mp3
# Saving file  56 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula330847.mp3
# Saving file  57 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula330846.mp3
# Saving file  58 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula330845.mp3
# Saving file  59 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula134267.mp3
# Saving file  60 / 60 : data/xeno-canto-dataset-full/Erithacusrubecula236804.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Streptopeliadecaocto/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Streptopelia%20decaocto%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  10  files
# A total of  10  files will be downloaded
# Saving file  1 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto477341.mp3
# Saving file  2 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto463201.mp3
# Saving file  3 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto343136.mp3
# Saving file  4 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto371972.mp3
# Saving file  5 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto315535.mp3
# Saving file  6 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto121001.mp3
# Saving file  7 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto103255.mp3
# Saving file  8 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto90942.mp3
# Saving file  9 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto90940.mp3
# Saving file  10 / 10 : data/xeno-canto-dataset-full/Streptopeliadecaocto90939.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Parusmajor/Poland for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Parus%20major%20cnt:Poland%20type:song&page=1
# Found  1  pages in total.
# Saved json for  149  files
# A total of  149  files will be downloaded
# Saving file  1 / 149 : data/xeno-canto-dataset-full/Parusmajor464829.mp3
# Saving file  2 / 149 : data/xeno-canto-dataset-full/Parusmajor464026.mp3
# Saving file  3 / 149 : data/xeno-canto-dataset-full/Parusmajor461644.mp3
# Saving file  4 / 149 : data/xeno-canto-dataset-full/Parusmajor461202.mp3
# Saving file  5 / 149 : data/xeno-canto-dataset-full/Parusmajor448603.mp3
# Saving file  6 / 149 : data/xeno-canto-dataset-full/Parusmajor406842.mp3
# Saving file  7 / 149 : data/xeno-canto-dataset-full/Parusmajor405253.mp3
# Saving file  8 / 149 : data/xeno-canto-dataset-full/Parusmajor405034.mp3
# Saving file  9 / 149 : data/xeno-canto-dataset-full/Parusmajor405033.mp3
# Saving file  10 / 149 : data/xeno-canto-dataset-full/Parusmajor405032.mp3
# Saving file  11 / 149 : data/xeno-canto-dataset-full/Parusmajor361594.mp3
# Saving file  12 / 149 : data/xeno-canto-dataset-full/Parusmajor358803.mp3
# Saving file  13 / 149 : data/xeno-canto-dataset-full/Parusmajor357502.mp3
# Saving file  14 / 149 : data/xeno-canto-dataset-full/Parusmajor320004.mp3
# Saving file  15 / 149 : data/xeno-canto-dataset-full/Parusmajor309370.mp3
# Saving file  16 / 149 : data/xeno-canto-dataset-full/Parusmajor306470.mp3
# Saving file  17 / 149 : data/xeno-canto-dataset-full/Parusmajor240468.mp3
# Saving file  18 / 149 : data/xeno-canto-dataset-full/Parusmajor237310.mp3
# ...
# Saving file  14 / 16 : data/xeno-canto-dataset-full/Emberizacitrinella362645.mp3
# Saving file  15 / 16 : data/xeno-canto-dataset-full/Emberizacitrinella362643.mp3
# Saving file  16 / 16 : data/xeno-canto-dataset-full/Emberizacitrinella246739.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Passerdomesticus/Czech for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Passer%20domesticus%20cnt:Czech%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Corvuscorone/Czech for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Corvus%20corone%20cnt:Czech%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Fringillacoelebs/Czech for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Fringilla%20coelebs%20cnt:Czech%20type:song&page=1
# Found  1  pages in total.
# Saved json for  8  files
# A total of  8  files will be downloaded
# Saving file  1 / 8 : data/xeno-canto-dataset-full/Fringillacoelebs77124.mp3
# Saving file  2 / 8 : data/xeno-canto-dataset-full/Fringillacoelebs76798.mp3
# Saving file  3 / 8 : data/xeno-canto-dataset-full/Fringillacoelebs75864.mp3
# Saving file  4 / 8 : data/xeno-canto-dataset-full/Fringillacoelebs75655.mp3
# Saving file  5 / 8 : data/xeno-canto-dataset-full/Fringillacoelebs75093.mp3
# Saving file  6 / 8 : data/xeno-canto-dataset-full/Fringillacoelebs46317.mp3
# Saving file  7 / 8 : data/xeno-canto-dataset-full/Fringillacoelebs36602.mp3
# Saving file  8 / 8 : data/xeno-canto-dataset-full/Fringillacoelebs475546.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Dendrocoposmajor/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Dendrocopos%20major%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Chlorischloris/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Chloris%20chloris%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  4  files
# A total of  4  files will be downloaded
# Saving file  1 / 4 : data/xeno-canto-dataset-full/Chlorischloris183377.mp3
# Saving file  2 / 4 : data/xeno-canto-dataset-full/Chlorischloris183371.mp3
# Saving file  3 / 4 : data/xeno-canto-dataset-full/Chlorischloris183370.mp3
# Saving file  4 / 4 : data/xeno-canto-dataset-full/Chlorischloris183368.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Corvusfrugilegus/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Corvus%20frugilegus%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Coccothraustescoccothraustes/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Coccothraustes%20coccothraustes%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Columbapalumbus/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Columba%20palumbus%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Delichonurbicum/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Delichon%20urbicum%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Apusapus/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Apus%20apus%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Sittaeuropaea/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Sitta%20europaea%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Corvusmonedula/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Corvus%20monedula%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Phoenicurusochruros/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Phoenicurus%20ochruros%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  1  files
# A total of  1  files will be downloaded
# Saving file  1 / 1 : data/xeno-canto-dataset-full/Phoenicurusochruros234539.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Turdusmerula/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Turdus%20merula%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  1  files
# A total of  1  files will be downloaded
# Saving file  1 / 1 : data/xeno-canto-dataset-full/Turdusmerula147898.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Turduspilaris/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Turdus%20pilaris%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Passermontanus/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Passer%20montanus%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Phylloscopustrochilus/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Phylloscopus%20trochilus%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  5  files
# A total of  5  files will be downloaded
# Saving file  1 / 5 : data/xeno-canto-dataset-full/Phylloscopustrochilus79031.mp3
# Saving file  2 / 5 : data/xeno-canto-dataset-full/Phylloscopustrochilus79030.mp3
# Saving file  3 / 5 : data/xeno-canto-dataset-full/Phylloscopustrochilus183172.mp3
# Saving file  4 / 5 : data/xeno-canto-dataset-full/Phylloscopustrochilus183171.mp3
# Saving file  5 / 5 : data/xeno-canto-dataset-full/Phylloscopustrochilus182508.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Phylloscopuscollybita/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Phylloscopus%20collybita%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  6  files
# A total of  6  files will be downloaded
# Saving file  1 / 6 : data/xeno-canto-dataset-full/Phylloscopuscollybita325329.mp3
# Saving file  2 / 6 : data/xeno-canto-dataset-full/Phylloscopuscollybita150260.mp3
# Saving file  3 / 6 : data/xeno-canto-dataset-full/Phylloscopuscollybita183175.mp3
# Saving file  4 / 6 : data/xeno-canto-dataset-full/Phylloscopuscollybita180113.mp3
# Saving file  5 / 6 : data/xeno-canto-dataset-full/Phylloscopuscollybita424463.mp3
# Saving file  6 / 6 : data/xeno-canto-dataset-full/Phylloscopuscollybita182524.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Phoenicurusphoenicurus/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Phoenicurus%20phoenicurus%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  3  files
# A total of  3  files will be downloaded
# Saving file  1 / 3 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus371646.mp3
# Saving file  2 / 3 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus186060.mp3
# Saving file  3 / 3 : data/xeno-canto-dataset-full/Phoenicurusphoenicurus186059.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Motacillaalba/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Motacilla%20alba%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Erithacusrubecula/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Erithacus%20rubecula%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  1  files
# A total of  1  files will be downloaded
# Saving file  1 / 1 : data/xeno-canto-dataset-full/Erithacusrubecula183388.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Streptopeliadecaocto/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Streptopelia%20decaocto%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Parusmajor/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Parus%20major%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  3  files
# A total of  3  files will be downloaded
# Saving file  1 / 3 : data/xeno-canto-dataset-full/Parusmajor182516.mp3
# Saving file  2 / 3 : data/xeno-canto-dataset-full/Parusmajor182514.mp3
# Saving file  3 / 3 : data/xeno-canto-dataset-full/Parusmajor182513.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Paruscaeruleus/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Parus%20caeruleus%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Alaudaarvensis/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Alauda%20arvensis%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Luscinialuscinia/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Luscinia%20luscinia%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  3  files
# A total of  3  files will be downloaded
# Saving file  1 / 3 : data/xeno-canto-dataset-full/Luscinialuscinia245720.mp3
# Saving file  2 / 3 : data/xeno-canto-dataset-full/Luscinialuscinia78935.mp3
# Saving file  3 / 3 : data/xeno-canto-dataset-full/Luscinialuscinia318797.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Garrulusglandarius/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Garrulus%20glandarius%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Turdusphilomelos/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Turdus%20philomelos%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  6  files
# A total of  6  files will be downloaded
# Saving file  1 / 6 : data/xeno-canto-dataset-full/Turdusphilomelos325362.mp3
# Saving file  2 / 6 : data/xeno-canto-dataset-full/Turdusphilomelos186077.mp3
# Saving file  3 / 6 : data/xeno-canto-dataset-full/Turdusphilomelos234365.mp3
# Saving file  4 / 6 : data/xeno-canto-dataset-full/Turdusphilomelos186074.mp3
# Saving file  5 / 6 : data/xeno-canto-dataset-full/Turdusphilomelos186073.mp3
# Saving file  6 / 6 : data/xeno-canto-dataset-full/Turdusphilomelos183476.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Picapica/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Pica%20pica%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Troglodytestroglodytes/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Troglodytes%20troglodytes%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Cardueliscarduelis/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Carduelis%20carduelis%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  1  files
# A total of  1  files will be downloaded
# Saving file  1 / 1 : data/xeno-canto-dataset-full/Cardueliscarduelis180114.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Sturnusvulgaris/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Sturnus%20vulgaris%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Emberizacitrinella/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Emberiza%20citrinella%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  7  files
# A total of  7  files will be downloaded
# Saving file  1 / 7 : data/xeno-canto-dataset-full/Emberizacitrinella424324.mp3
# Saving file  2 / 7 : data/xeno-canto-dataset-full/Emberizacitrinella186068.mp3
# Saving file  3 / 7 : data/xeno-canto-dataset-full/Emberizacitrinella186066.mp3
# Saving file  4 / 7 : data/xeno-canto-dataset-full/Emberizacitrinella183373.mp3
# Saving file  5 / 7 : data/xeno-canto-dataset-full/Emberizacitrinella183372.mp3
# Saving file  6 / 7 : data/xeno-canto-dataset-full/Emberizacitrinella183369.mp3
# Saving file  7 / 7 : data/xeno-canto-dataset-full/Emberizacitrinella182509.mp3
# Creating subdirectory ../data/xeno-canto-dataset-full/Passerdomesticus/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Passer%20domesticus%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Corvuscorone/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Corvus%20corone%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-full/Fringillacoelebs/Lithuania for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Fringilla%20coelebs%20cnt:Lithuania%20type:song&page=1
# Found  1  pages in total.
# Saved json for  6  files
# A total of  6  files will be downloaded
# Saving file  1 / 6 : data/xeno-canto-dataset-full/Fringillacoelebs478552.mp3
# Saving file  2 / 6 : data/xeno-canto-dataset-full/Fringillacoelebs183482.mp3
# Saving file  3 / 6 : data/xeno-canto-dataset-full/Fringillacoelebs183386.mp3
# Saving file  4 / 6 : data/xeno-canto-dataset-full/Fringillacoelebs183168.mp3
# Saving file  5 / 6 : data/xeno-canto-dataset-full/Fringillacoelebs182511.mp3
# Saving file  6 / 6 : data/xeno-canto-dataset-full/Fringillacoelebs179680.mp3
