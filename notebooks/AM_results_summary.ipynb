# %% [markdown]
# # Results
#
# The file contains results for different architectures of CNN's tested. Presented Classification Reports were calculated on a test set (10% of a whole dataset).
# * Maximum number of classes tested is 19
# * Each CNN is trained on 5-sec Melspectrograms filtered with high-pass filters
# * Classes are highly imbalanced: smallest class have 74 samples in the test set, whreaes the biggest have 3741

# %% [markdown]
# # Dataset
#
#
#
#     birds = ['Dendrocopos major',
#              'Chloris chloris',
#              'Corvus frugilegus',
#              'Coccothraustes coccothraustes',
#              'Columba palumbus',
#              'Delichon urbicum',
#              'Apus apus',
#              'Sitta europaea',
#              'Corvus monedula',
#              'Phoenicurus ochruros',
#              'Turdus merula',
#              'Turdus pilaris',
#              'Passer montanus',
#              'Phylloscopus trochilus',
#              'Phylloscopus collybita',
#              'Phoenicurus phoenicurus',
#              'Motacilla alba',
#              'Erithacus rubecula',
#              'Streptopelia decaocto',
#              'Parus major',
#              'Parus caeruleus',
#              'Alauda arvensis',
#              'Luscinia luscinia',
#              'Garrulus glandarius',
#              'Turdus philomelos',
#              'Pica pica',
#              'Troglodytes troglodytes',
#              'Carduelis carduelis',
#              'Sturnus vulgaris',
#              'Emberiza citrinella',
#              'Passer domesticus',
#              'Corvus corone',
#              'Fringilla coelebs']
#
#
# # 5-class
# countries = ['Poland', 'Germany', 'Slovakia', 'Czech', 'Lithuania']
#
# Birds:
# ['AcrocephalusArundinaceus', 'PhylloscopusCollybita', 'EmberizaCitrinella', 'SylviaAtricapilla', 'ParusMajor']
#
# ### Sound
#
# Found  154  mp3 files for  AcrocephalusArundinaceus
# Size of train:  123 , val:  15 , test:  15
#
# Found  310  mp3 files for  PhylloscopusCollybita
# Size of train:  248 , val:  31 , test:  31
#
# Found  326  mp3 files for  EmberizaCitrinella
# Size of train:  260 , val:  32 , test:  32
#
# Found  566  mp3 files for  SylviaAtricapilla
# Size of train:  452 , val:  56 , test:  56
#
# Found  414  mp3 files for  ParusMajor
# Size of train:  331 , val:  41 , test:  41
#
# ### Images
#
# Found  8079  files for  Ember
#
# Found  5554  files for  Phyll
#
# Found  3728  files for  Acroc
#
# Found  8268  files for  Parus
#
# Found  22529  files for  Sylvi
#
#
# # 19 - class
# countries = ['Poland', 'Germany', 'Slovakia', 'Czech', 'Lithuania']
#
# ### Sound
# Found  418  mp3 files for  Parusmajor
# Size of train:  334 , val:  41 , test:  41
#
# Found  59  mp3 files for  Passerdomesticus
# Size of train:  47 , val:  5 , test:  5
#
# Found  107  mp3 files for  Luscinialuscinia
# Size of train:  85 , val:  10 , test:  10
#
# Found  111  mp3 files for  Phoenicurusphoenicurus
# Size of train:  88 , val:  11 , test:  11
#
# Found  446  mp3 files for  Erithacusrubecula
# Size of train:  356 , val:  44 , test:  44
#
# Found  80  mp3 files for  Phoenicurusochruros
# Size of train:  64 , val:  8 , test:  8
#
# Found  134  mp3 files for  Sittaeuropaea
# Size of train:  107 , val:  13 , test:  13
#
# Found  105  mp3 files for  Alaudaarvensis
# Size of train:  84 , val:  10 , test:  10
#
# Found  216  mp3 files for  Phylloscopustrochilus
# Size of train:  172 , val:  21 , test:  21
#
# Found  564  mp3 files for  Turdusphilomelos
# Size of train:  451 , val:  56 , test:  56
#
# Found  314  mp3 files for  Phylloscopuscollybita
# Size of train:  251 , val:  31 , test:  31
#
# Found  365  mp3 files for  Fringillacoelebs
# Size of train:  292 , val:  36 , test:  36
#
# Found  65  mp3 files for  Sturnusvulgaris
# Size of train:  52 , val:  6 , test:  6
#
# Found  329  mp3 files for  Emberizacitrinella
# Size of train:  263 , val:  32 , test:  32
#
# Found  58  mp3 files for  Columbapalumbus
# Size of train:  46 , val:  5 , test:  5
#
# Found  204  mp3 files for  Troglodytestroglodytes
# Size of train:  163 , val:  20 , test:  20
#
# Found  53  mp3 files for  Cardueliscarduelis
# Size of train:  42 , val:  5 , test:  5
#
# Found  97  mp3 files for  Chlorischloris
# Size of train:  77 , val:  9 , test:  9
#
# Found  667  mp3 files for  Turdusmerula
# Size of train:  533 , val:  66 , test:  66
#
# ### Images
# Found  21116  files for  4Erith
#
# Found  1238  files for  17Chlor
#
# Found  4481  files for  8Phyll
#
# Found  1246  files for  1Passe
#
# Found  9905  files for  13Ember
#
# Found  2117  files for  6Sitta
#
# Found  977  files for  14Colum
#
# Found  762  files for  16Cardu
#
# Found  1675  files for  5Phoen
#
# Found  5615  files for  10Phyll
#
# Found  29079  files for  18Turdu
#
# Found  35756  files for  9Turdu
#
# Found  10376  files for  11Fring
#
# Found  3107  files for  2Lusci
#
# Found  8577  files for  0Parus
#
# Found  5226  files for  15Trogl
#
# Found  3117  files for  12Sturn
#
# Found  2188  files for  7Alaud
#
# Found  2715  files for  3Phoen
#
# # 27 - class
# all countries
#
# Selected random files number:
#  train:  1544 / 1544 , val:  193 / 193 , test:  194 / 194
# Selected random files number:
#  train:  98 / 98 , val:  12 / 12 , test:  13 / 13
# Selected random files number:
#  train:  307 / 307 , val:  38 / 38 , test:  39 / 39
# Selected random files number:
#  train:  316 / 316 , val:  39 / 39 , test:  41 / 41
# Selected random files number:
#  train:  414 / 414 , val:  51 / 51 , test:  53 / 53
# Selected random files number:
#  train:  1269 / 1269 , val:  158 / 158 , test:  160 / 160
# Selected random files number:
#  train:  44 / 44 , val:  5 / 5 , test:  7 / 7
# Selected random files number:
#  train:  286 / 286 , val:  35 / 35 , test:  37 / 37
# Selected random files number:
#  train:  108 / 108 , val:  13 / 13 , test:  15 / 15
# Selected random files number:
#  train:  146 / 146 , val:  18 / 18 , test:  19 / 19
# Selected random files number:
#  train:  71 / 71 , val:  8 / 8 , test:  10 / 10
# Selected random files number:
#  train:  311 / 311 , val:  38 / 38 , test:  40 / 40
# Selected random files number:
#  train:  697 / 697 , val:  87 / 87 , test:  88 / 88
# Selected random files number:
#  train:  251 / 251 , val:  31 / 31 , test:  32 / 32
# Selected random files number:
#  train:  1723 / 1723 , val:  215 / 215 , test:  216 / 216
# Selected random files number:
#  train:  45 / 45 , val:  5 / 5 , test:  7 / 7
# Selected random files number:
#  train:  1512 / 1512 , val:  189 / 189 , test:  189 / 189
# Selected random files number:
#  train:  1301 / 1301 , val:  162 / 162 , test:  164 / 164
# Selected random files number:
#  train:  1712 / 1712 , val:  214 / 214 , test:  215 / 215
# Selected random files number:
#  train:  304 / 304 , val:  38 / 38 , test:  38 / 38
# Selected random files number:
#  train:  1161 / 1161 , val:  145 / 145 , test:  146 / 146
# Selected random files number:
#  train:  212 / 212 , val:  26 / 26 , test:  27 / 27
# Selected random files number:
#  train:  1036 / 1036 , val:  129 / 129 , test:  131 / 131
# Selected random files number:
#  train:  502 / 502 , val:  62 / 62 , test:  64 / 64
# Selected random files number:
#  train:  501 / 501 , val:  62 / 62 , test:  64 / 64
# Selected random files number:
#  train:  126 / 126 , val:  15 / 15 , test:  17 / 17
# Selected random files number:
#  train:  1636 / 1636 , val:  204 / 204 , test:  205 / 205

# %% [markdown]
# ## MobileNet
#
# ### 5-class
# AM_mobilenetV2.h5

# %% [markdown]
# ## Xception
#
# ### 19- class
# AM_xception_19classes.h5
#
#
#
# AM_xception_19classes2.h5
#
#
#
# #### AM_xception_19classesv2.h5
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#       0Parus       0.81      0.78      0.79       959
#       1Passe       0.79      0.35      0.49        97
#       2Lusci       0.75      0.77      0.76       291
#       3Phoen       0.72      0.41      0.52       408
#       4Erith       0.65      0.75      0.69      2550
#       5Phoen       0.57      0.61      0.59       102
#       6Sitta       0.26      0.63      0.37       187
#       7Alaud       0.48      0.93      0.63       210
#       8Phyll       0.28      0.73      0.40       491
#       9Turdu       0.76      0.71      0.73      3741
#      10Phyll       0.68      0.69      0.69       581
#      11Fring       0.73      0.63      0.68       882
#      13Ember       0.80      0.50      0.61      1717
#      15Trogl       0.79      0.58      0.67       840
#      17Chlor       0.18      0.81      0.29        74
#      18Turdu       0.77      0.65      0.71      2713
#
#     accuracy                           0.67     15843
#    macro avg       0.63      0.66      0.60     15843
# weighted avg       0.72      0.67      0.68     15843
#
#
#
# AM_xception_19classesv2_2.h5
#
# ### 16- class
# AM_xception_16classes_callback.h5
# Results:

# %% [markdown]
# ![eff](https://raw.githubusercontent.com/tensorflow/tpu/master/models/official/efficientnet/g3doc/params.png)
#
#
# ## EfficientNet B0
#
#
# ### 19- class
#
# #### AM_efficientnet_19classes_callback.h5
#
# Classification Report
#
#               precision    recall  f1-score   support
#       0Parus       0.67      0.83      0.75       959
#       1Passe       0.63      0.33      0.43        97
#       2Lusci       0.79      0.64      0.70       291
#       3Phoen       0.52      0.41      0.46       408
#       4Erith       0.66      0.61      0.64      2550
#       5Phoen       0.36      0.42      0.39       102
#       6Sitta       0.26      0.31      0.28       187
#       7Alaud       0.65      0.94      0.77       210
#       8Phyll       0.75      0.54      0.63       491
#       9Turdu       0.76      0.66      0.71      3741
#      10Phyll       0.72      0.65      0.68       581
#      11Fring       0.60      0.63      0.62       882
#      12Sturn       0.35      0.21      0.26       423
#      13Ember       0.75      0.55      0.63      1717
#      14Colum       0.00      0.00      0.00       205
#      15Trogl       0.81      0.40      0.54       840
#      16Cardu       0.18      0.43      0.26       114
#      17Chlor       0.30      0.55      0.39        74
#      18Turdu       0.56      0.86      0.67      2713
#
#     accuracy                           0.63     16585
#    macro avg       0.54      0.52      0.52     16585
# weighted avg       0.66      0.63      0.63     16585
#
#
#
# ## EfficientNet B3
#
# ### 19- class
#
# #### AM_efficientnet_19classes_callbackb3.h5
#
# Classification Report
#                   precision    recall  f1-score   support
#
#       0Parus       0.80      0.82      0.81       959
#       1Passe       0.61      0.62      0.62        97
#       2Lusci       0.97      0.76      0.85       291
#       3Phoen       0.97      0.42      0.59       408
#       4Erith       0.64      0.86      0.73      2550
#       5Phoen       0.66      0.63      0.64       102
#       6Sitta       0.37      0.44      0.40       187
#       7Alaud       0.88      0.94      0.91       210
#       8Phyll       0.87      0.58      0.70       491
#       9Turdu       0.87      0.70      0.78      3741
#      10Phyll       0.81      0.68      0.74       581
#      11Fring       0.44      0.80      0.57       882
#      12Sturn       0.41      0.31      0.35       423
#      13Ember       0.80      0.72      0.76      1717
#      14Colum       0.03      0.02      0.03       205
#      15Trogl       0.79      0.57      0.66       840
#      16Cardu       0.97      0.61      0.75       114
#      17Chlor       0.57      0.58      0.58        74
#      18Turdu       0.73      0.78      0.75      2713
#
#     accuracy                           0.72     16585
#    macro avg       0.69      0.62      0.64     16585
# weighted avg       0.74      0.72      0.72     16585
#
#
# ## EfficientNet B5
#
# ### 19- class
#
# #### AM_efficientnet_19classes_callbackB5.h5
#
#
#
#
# ## EfficientNet B6
#
# ### 19- class
#
# #### AM_efficientnet_19classes_callbackB6.h5
#
#
#
#
# ## EfficientNet B7
# ### 19- class
#
# #### AM_efficientnet_19classes_callbackB7.h5
